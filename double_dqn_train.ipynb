# %%
import os, random, math, numpy as np, torch, torch.nn as nn, torch.optim as optim
from collections import deque

os.environ.setdefault("SDL_VIDEODRIVER", "dummy")
os.environ.setdefault("SDL_AUDIODRIVER", "dummy")
DEFAULT_CHECKPOINT_DIR = "/kaggle/working"
os.makedirs(DEFAULT_CHECKPOINT_DIR, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

CHECKPOINT_PATH = os.path.join(DEFAULT_CHECKPOINT_DIR, "double_dqn_flappy.pth")

# --- Hyperparameters ---
EPI_NUMS = 30000
LR = 5e-5
BATCH_SIZE = 128
BUFFER_SIZE = 100000
GAMMA = 0.995
TAU = 0.001
EPSILON_DECAY = 80000
EPSILON_START = 1.0
EPSILON_FINAL = 0.01
WARMUP_STEPS = 10000
MAX_STEPS = 6000

# --- Replay Buffer ---
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = map(np.array, zip(*batch))
        return (
            torch.FloatTensor(state),
            torch.LongTensor(action),
            torch.FloatTensor(reward),
            torch.FloatTensor(next_state),
            torch.FloatTensor(done),
        )

    def __len__(self):
        return len(self.buffer)

class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, output_dim)
        )

    def forward(self, x):
        return self.net(x)


class Agent:
    def __init__(self, state_dim=4, n_actions=2):
        self.device = device
        self.n_actions = n_actions
        self.policy_net = DQN(state_dim, n_actions).to(device)
        self.target_net = DQN(state_dim, n_actions).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=LR)
        self.loss_fn = nn.SmoothL1Loss()

    def act(self, state, epsilon):
        if random.random() < epsilon:
            return random.randint(0, self.n_actions - 1)
        state_v = torch.FloatTensor(state).unsqueeze(0).to(device)
        q_vals = self.policy_net(state_v)
        return q_vals.argmax().item()

    def update(self, buffer, batch_size):
        if len(buffer) < batch_size:
            return None

        state, action, reward, next_state, done = buffer.sample(batch_size)
        state, action, reward, next_state, done = (
            state.to(device),
            action.to(device),
            reward.to(device),
            next_state.to(device),
            done.to(device),
        )

        # Q-values hiện tại
        q_values = self.policy_net(state).gather(1, action.unsqueeze(1)).squeeze(1)

        # Double DQN: policy chọn action, target đánh giá
        next_actions = self.policy_net(next_state).argmax(1)
        next_q_values = self.target_net(next_state).gather(1, next_actions.unsqueeze(1)).squeeze(1)
        expected_q = reward + GAMMA * next_q_values * (1 - done)

        # Loss
        loss = self.loss_fn(q_values, expected_q.detach())

        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0)
        self.optimizer.step()

        # Soft update
        for target_param, param in zip(self.target_net.parameters(), self.policy_net.parameters()):
            target_param.data.copy_(TAU * param.data + (1.0 - TAU) * target_param.data)

        return loss.item()

    def save(self, path):
        torch.save({
            'policy_state_dict': self.policy_net.state_dict(),
            'target_state_dict': self.target_net.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
        }, path)

    def load(self, path):
        checkpoint = torch.load(path, map_location=device)
        self.policy_net.load_state_dict(checkpoint['policy_state_dict'])
        self.target_net.load_state_dict(checkpoint.get('target_state_dict', checkpoint['policy_state_dict']))
        if 'optimizer_state_dict' in checkpoint:
            self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        print(f" Loaded checkpoint from {path}")


#  Environment ---
class FlappyBirdEnv:
    def __init__(self, difficulty='normal', seed=None):
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)
        presets = {
            'easy':  {'PIPE_GAP':220,'PIPE_SPACING':300,'SCROLL_SPEED':2},
            'normal':{'PIPE_GAP':180,'PIPE_SPACING':280,'SCROLL_SPEED':3},
            'hard':  {'PIPE_GAP':150,'PIPE_SPACING':260,'SCROLL_SPEED':3}
        }
        p = presets[difficulty]
        self.PIPE_GAP = p['PIPE_GAP']
        self.PIPE_SPACING = p['PIPE_SPACING']
        self.SCROLL_SPEED = p['SCROLL_SPEED']
        self.GRAVITY = 0.5
        self.FLAP_VEL = -9.0
        self.MAX_VEL = 12.0
        self.SCREEN_WIDTH = 288
        self.SCREEN_HEIGHT = 512
        self.GROUND_HEIGHT = 112
        self.pipe_width = 52
        self.INIT_PIPE_OFFSET = 100
        self.MIN_GAP_Y = 50
        self.LIVING_REWARD = 0.1
        self.SCORE_REWARD = 10.0
        self.DEATH_PENALTY = -7
        self.VERTICAL_WEIGHT = 0.3
        self.VELOCITY_WEIGHT = 0.1
        self.CENTER_BONUS_MULT = 5.0
        self.APPROACHING_THRESHOLD = 0.3
        self.APPROACHING_MULTIPLIER = 2.0
        self.reset()

    def reset(self):
        self.bird_x = 80
        self.bird_y = self.SCREEN_HEIGHT//2
        self.bird_vel = 0.0
        self.pipes = []
        start_x = self.SCREEN_WIDTH + self.INIT_PIPE_OFFSET
        for i in range(3):
            gy = random.randint(self.MIN_GAP_Y, self.SCREEN_HEIGHT - self.MIN_GAP_Y - self.PIPE_GAP)
            self.pipes.append([start_x + i*self.PIPE_SPACING, gy])
        self.done = False
        self.score = 0
        self.scored_pipes = set()
        return self._get_state()

    def step(self, action):
        if action == 1:
            self.bird_vel = self.FLAP_VEL
        self.bird_vel += self.GRAVITY
        self.bird_vel = np.clip(self.bird_vel, -self.MAX_VEL, self.MAX_VEL)
        self.bird_y += self.bird_vel
        for p in self.pipes: p[0] -= self.SCROLL_SPEED
        if (self.pipes[0][0] + self.pipe_width) < 0:
            self.pipes.pop(0)
            new_x = self.pipes[-1][0] + self.PIPE_SPACING
            gy = random.randint(self.MIN_GAP_Y, self.SCREEN_HEIGHT - self.MIN_GAP_Y - self.PIPE_GAP)
            self.pipes.append([new_x, gy])
        if self._check_collision():
            self.done = True
            return self._get_state(), self.DEATH_PENALTY, True, {}
        just_scored = False
        for pipe in self.pipes:
            px, gy = pipe
            if (px + self.pipe_width) < self.bird_x and id(pipe) not in self.scored_pipes:
                if gy < self.bird_y < gy + self.PIPE_GAP:
                    self.score += 1
                    just_scored = True
                self.scored_pipes.add(id(pipe))
        dy_norm, vel_norm, dx_norm = self._get_normalized_values()
        if just_scored:
            reward = self.SCORE_REWARD + max(0, (1.0 - abs(dy_norm)) * self.CENTER_BONUS_MULT)
        else:
            reward = self.LIVING_REWARD - abs(dy_norm)*self.VERTICAL_WEIGHT - abs(vel_norm)*self.VELOCITY_WEIGHT
            if dx_norm < self.APPROACHING_THRESHOLD:
                reward *= self.APPROACHING_MULTIPLIER
        return self._get_state(), reward, self.done, {}

    def _check_collision(self):
        GROUND_Y = self.SCREEN_HEIGHT - self.GROUND_HEIGHT
        if self.bird_y <= 0 or self.bird_y >= GROUND_Y: return True
        for px, gy in self.pipes:
            if (self.bird_x + 12) > px and (self.bird_x - 12) < (px + self.pipe_width):
                if self.bird_y - 12 < gy or self.bird_y + 12 > gy + self.PIPE_GAP:
                    return True
        return False

    def _get_next_pipe(self):
        for px, gy in self.pipes:
            if px + self.pipe_width >= self.bird_x:
                return px, gy
        return self.pipes[0]

    def _get_normalized_values(self):
        px, gy = self._get_next_pipe()
        gap_center = gy + self.PIPE_GAP/2
        dy = (gap_center - self.bird_y)/float(self.PIPE_GAP)
        vel = self.bird_vel/self.MAX_VEL
        dx = (px - self.bird_x)/self.SCREEN_WIDTH
        return dy, vel, dx

    def _get_state(self):
        px, gy = self._get_next_pipe()
        gap_center = gy + self.PIPE_GAP/2
        dy = (gap_center - self.bird_y)/float(self.PIPE_GAP)
        vel = self.bird_vel/self.MAX_VEL
        dist = (px - self.bird_x)/self.SCREEN_WIDTH
        gap_y = gy/self.SCREEN_HEIGHT
        return np.array([dy, vel, dist, gap_y], dtype=np.float32)


def train_loop(num_episodes=EPI_NUMS, resume=False, difficulty="normal"):
    env = FlappyBirdEnv(difficulty=difficulty)
    agent = Agent()
    buffer = ReplayBuffer(BUFFER_SIZE)

    if resume and os.path.exists(CHECKPOINT_PATH):
        agent.load(CHECKPOINT_PATH)

    total_steps, losses, scores = 0, [], []

    print(f"Collecting {WARMUP_STEPS} random transitions for warmup...")
    state = env.reset()
    for _ in range(WARMUP_STEPS):
        a = random.randint(0, 1)
        ns, r, d, _ = env.step(a)
        buffer.push(state, a, r, ns, float(d))
        state = env.reset() if d else ns
    print(f"Warmup finished. Replay buffer size = {len(buffer)}")

    for ep in range(1, num_episodes+1):
        s = env.reset()
        done, ep_r = False, 0
        while not done:
            eps = EPSILON_FINAL + (EPSILON_START - EPSILON_FINAL) * math.exp(-total_steps/EPSILON_DECAY)
            a = agent.act(s, eps)
            ns, r, done, _ = env.step(a)
            buffer.push(s, a, r, ns, float(done))
            loss = agent.update(buffer, BATCH_SIZE)
            if loss: losses.append(loss)
            s = ns
            ep_r += r
            total_steps += 1

        scores.append(env.score)
        if ep % 50 == 0:
            print(f"Ep {ep:5d} | Steps {total_steps:7d} | Score {env.score:3d} | "
                  f"EpReward {ep_r:6.2f} | Eps {eps:.3f} | "
                  f"AvgScore50 {np.mean(scores[-50:]):.2f} | AvgLoss100 {np.mean(losses[-100:]):.4f}")
            agent.save(CHECKPOINT_PATH)

    agent.save(CHECKPOINT_PATH)
    print("Training finished. Model saved to", CHECKPOINT_PATH)

# run training
train_loop(num_episodes=EPI_NUMS, difficulty="hard", resume=False)
# Out:
# Using device: cuda
# Collecting 10000 random transitions for warmup...
# Warmup finished. Replay buffer size = 10000
# Ep    50 | Steps    1684 | Score   0 | EpReward -21.54 | Eps 0.979 | AvgScore50 0.00 | AvgLoss100 0.1447
# Ep   100 | Steps    3376 | Score   0 | EpReward -10.17 | Eps 0.959 | AvgScore50 0.00 | AvgLoss100 0.1161
# Ep   150 | Steps    5062 | Score   0 | EpReward -13.39 | Eps 0.939 | AvgScore50 0.00 | AvgLoss100 0.0693
# Ep   200 | Steps    6765 | Score   0 | EpReward -10.21 | Eps 0.920 | AvgScore50 0.00 | AvgLoss100 0.0357
# Ep   250 | Steps    8479 | Score   0 | EpReward -12.54 | Eps 0.900 | AvgScore50 0.00 | AvgLoss100 0.0166
# Ep   300 | Steps   10183 | Score   0 | EpReward -19.92 | Eps 0.882 | AvgScore50 0.00 | AvgLoss100 0.0158
# Ep   350 | Steps   11902 | Score   0 | EpReward -10.10 | Eps 0.863 | AvgScore50 0.00 | AvgLoss100 0.0262
# Ep   400 | Steps   13642 | Score   0 | EpReward -11.78 | Eps 0.845 | AvgScore50 0.00 | AvgLoss100 0.0374
# Ep   450 | Steps   15338 | Score   0 | EpReward -19.16 | Eps 0.827 | AvgScore50 0.00 | AvgLoss100 0.0482
# Ep   500 | Steps   17112 | Score   0 | EpReward -22.75 | Eps 0.809 | AvgScore50 0.00 | AvgLoss100 0.0502
# Ep   550 | Steps   18839 | Score   0 | EpReward -13.87 | Eps 0.792 | AvgScore50 0.00 | AvgLoss100 0.0673
# Ep   600 | Steps   20610 | Score   0 | EpReward -20.19 | Eps 0.775 | AvgScore50 0.00 | AvgLoss100 0.0670
# Ep   650 | Steps   22387 | Score   0 | EpReward -11.69 | Eps 0.758 | AvgScore50 0.00 | AvgLoss100 0.0657
# Ep   700 | Steps   24142 | Score   0 | EpReward -20.85 | Eps 0.742 | AvgScore50 0.00 | AvgLoss100 0.0584
# Ep   750 | Steps   25861 | Score   0 | EpReward -10.19 | Eps 0.727 | AvgScore50 0.00 | AvgLoss100 0.0544
# Ep   800 | Steps   27661 | Score   0 | EpReward  -9.91 | Eps 0.711 | AvgScore50 0.00 | AvgLoss100 0.0445
# Ep   850 | Steps   29465 | Score   0 | EpReward -12.25 | Eps 0.695 | AvgScore50 0.00 | AvgLoss100 0.0327
# Ep   900 | Steps   31276 | Score   0 | EpReward -14.91 | Eps 0.680 | AvgScore50 0.00 | AvgLoss100 0.0204
# Ep   950 | Steps   33073 | Score   0 | EpReward -13.43 | Eps 0.665 | AvgScore50 0.00 | AvgLoss100 0.0104
# Ep  1000 | Steps   34922 | Score   0 | EpReward -20.32 | Eps 0.650 | AvgScore50 0.00 | AvgLoss100 0.0070
# Ep  1050 | Steps   36710 | Score   0 | EpReward -10.61 | Eps 0.636 | AvgScore50 0.00 | AvgLoss100 0.0033
# Ep  1100 | Steps   38549 | Score   0 | EpReward -19.40 | Eps 0.621 | AvgScore50 0.00 | AvgLoss100 0.0034
# Ep  1150 | Steps   40372 | Score   0 | EpReward -10.19 | Eps 0.608 | AvgScore50 0.00 | AvgLoss100 0.0027
# Ep  1200 | Steps   42203 | Score   0 | EpReward -21.21 | Eps 0.594 | AvgScore50 0.00 | AvgLoss100 0.0023
# Ep  1250 | Steps   44049 | Score   0 | EpReward -18.28 | Eps 0.581 | AvgScore50 0.00 | AvgLoss100 0.0029
# Ep  1300 | Steps   45882 | Score   0 | EpReward -20.86 | Eps 0.568 | AvgScore50 0.00 | AvgLoss100 0.0030
# Ep  1350 | Steps   47771 | Score   0 | EpReward -20.17 | Eps 0.555 | AvgScore50 0.00 | AvgLoss100 0.0028
# Ep  1400 | Steps   49600 | Score   0 | EpReward -17.24 | Eps 0.543 | AvgScore50 0.00 | AvgLoss100 0.0028
# Ep  1450 | Steps   51448 | Score   0 | EpReward -12.03 | Eps 0.530 | AvgScore50 0.00 | AvgLoss100 0.0037
# Ep  1500 | Steps   53331 | Score   0 | EpReward -19.82 | Eps 0.518 | AvgScore50 0.00 | AvgLoss100 0.0034
# Ep  1550 | Steps   55226 | Score   0 | EpReward -10.89 | Eps 0.506 | AvgScore50 0.00 | AvgLoss100 0.0031
# Ep  1600 | Steps   57109 | Score   0 | EpReward -11.05 | Eps 0.495 | AvgScore50 0.00 | AvgLoss100 0.0026
# Ep  1650 | Steps   58973 | Score   0 | EpReward -13.25 | Eps 0.484 | AvgScore50 0.00 | AvgLoss100 0.0025
# Ep  1700 | Steps   60917 | Score   0 | EpReward -10.20 | Eps 0.472 | AvgScore50 0.00 | AvgLoss100 0.0026
# Ep  1750 | Steps   62856 | Score   0 | EpReward -10.13 | Eps 0.461 | AvgScore50 0.00 | AvgLoss100 0.0026
# Ep  1800 | Steps   64849 | Score   0 | EpReward -10.95 | Eps 0.450 | AvgScore50 0.00 | AvgLoss100 0.0020
# Ep  1850 | Steps   66829 | Score   0 | EpReward  -9.90 | Eps 0.439 | AvgScore50 0.00 | AvgLoss100 0.0017
# Ep  1900 | Steps   68833 | Score   0 | EpReward -10.17 | Eps 0.429 | AvgScore50 0.00 | AvgLoss100 0.0014
# Ep  1950 | Steps   70737 | Score   0 | EpReward -14.11 | Eps 0.419 | AvgScore50 0.00 | AvgLoss100 0.0017
# Ep  2000 | Steps   72804 | Score   0 | EpReward -17.28 | Eps 0.408 | AvgScore50 0.00 | AvgLoss100 0.0014
# Ep  2050 | Steps   74797 | Score   0 | EpReward  -9.97 | Eps 0.399 | AvgScore50 0.00 | AvgLoss100 0.0014
# Ep  2100 | Steps   76805 | Score   0 | EpReward  -9.96 | Eps 0.389 | AvgScore50 0.00 | AvgLoss100 0.0014
# Ep  2150 | Steps   78805 | Score   0 | EpReward -11.76 | Eps 0.380 | AvgScore50 0.00 | AvgLoss100 0.0013
# Ep  2200 | Steps   80817 | Score   0 | EpReward -11.61 | Eps 0.371 | AvgScore50 0.00 | AvgLoss100 0.0013
# Ep  2250 | Steps   82966 | Score   0 | EpReward -14.95 | Eps 0.361 | AvgScore50 0.00 | AvgLoss100 0.0013
# Ep  2300 | Steps   84959 | Score   0 | EpReward  -9.98 | Eps 0.352 | AvgScore50 0.00 | AvgLoss100 0.0011
# Ep  2350 | Steps   87014 | Score   0 | EpReward -10.20 | Eps 0.344 | AvgScore50 0.00 | AvgLoss100 0.0014
# Ep  2400 | Steps   89087 | Score   0 | EpReward -10.19 | Eps 0.335 | AvgScore50 0.00 | AvgLoss100 0.0018
# Ep  2450 | Steps   91328 | Score   0 | EpReward -10.29 | Eps 0.326 | AvgScore50 0.00 | AvgLoss100 0.0011
# Ep  2500 | Steps   93361 | Score   0 | EpReward -16.17 | Eps 0.318 | AvgScore50 0.00 | AvgLoss100 0.0011
# Ep  2550 | Steps   95688 | Score   0 | EpReward -11.38 | Eps 0.309 | AvgScore50 0.00 | AvgLoss100 0.0013
# Ep  2600 | Steps   97856 | Score   0 | EpReward -12.26 | Eps 0.301 | AvgScore50 0.00 | AvgLoss100 0.0013
# Ep  2650 | Steps  100105 | Score   0 | EpReward -21.77 | Eps 0.293 | AvgScore50 0.00 | AvgLoss100 0.0015
# Ep  2700 | Steps  102209 | Score   0 | EpReward -18.77 | Eps 0.286 | AvgScore50 0.00 | AvgLoss100 0.0031
# Ep  2750 | Steps  104601 | Score   0 | EpReward -15.59 | Eps 0.278 | AvgScore50 0.00 | AvgLoss100 0.0022
# Ep  2800 | Steps  107017 | Score   0 | EpReward -20.84 | Eps 0.270 | AvgScore50 0.00 | AvgLoss100 0.0028
# Ep  2850 | Steps  109632 | Score   0 | EpReward -22.35 | Eps 0.261 | AvgScore50 0.00 | AvgLoss100 0.0034
# Ep  2900 | Steps  112044 | Score   0 | EpReward -20.24 | Eps 0.254 | AvgScore50 0.00 | AvgLoss100 0.0041
# Ep  2950 | Steps  114547 | Score   0 | EpReward -14.74 | Eps 0.246 | AvgScore50 0.00 | AvgLoss100 0.0038
# Ep  3000 | Steps  117026 | Score   0 | EpReward -14.08 | Eps 0.239 | AvgScore50 0.00 | AvgLoss100 0.0053
# Ep  3050 | Steps  119677 | Score   0 | EpReward -11.95 | Eps 0.232 | AvgScore50 0.00 | AvgLoss100 0.0065
# Ep  3100 | Steps  122474 | Score   0 | EpReward -10.06 | Eps 0.224 | AvgScore50 0.00 | AvgLoss100 0.0058
# Ep  3150 | Steps  125287 | Score   0 | EpReward -10.14 | Eps 0.217 | AvgScore50 0.00 | AvgLoss100 0.0081
# Ep  3200 | Steps  128097 | Score   0 | EpReward -10.44 | Eps 0.210 | AvgScore50 0.02 | AvgLoss100 0.0055
# Ep  3250 | Steps  130906 | Score   0 | EpReward -10.23 | Eps 0.203 | AvgScore50 0.00 | AvgLoss100 0.0086
# Ep  3300 | Steps  133580 | Score   0 | EpReward -20.13 | Eps 0.196 | AvgScore50 0.00 | AvgLoss100 0.0105
# Ep  3350 | Steps  136224 | Score   0 | EpReward -14.97 | Eps 0.190 | AvgScore50 0.00 | AvgLoss100 0.0080
# Ep  3400 | Steps  139083 | Score   0 | EpReward -22.86 | Eps 0.184 | AvgScore50 0.00 | AvgLoss100 0.0146
# Ep  3450 | Steps  142040 | Score   0 | EpReward -13.02 | Eps 0.178 | AvgScore50 0.00 | AvgLoss100 0.0146
# Ep  3500 | Steps  144863 | Score   0 | EpReward -17.25 | Eps 0.172 | AvgScore50 0.00 | AvgLoss100 0.0150
# Ep  3550 | Steps  148010 | Score   0 | EpReward -26.32 | Eps 0.166 | AvgScore50 0.00 | AvgLoss100 0.0196
# Ep  3600 | Steps  151326 | Score   0 | EpReward -22.05 | Eps 0.159 | AvgScore50 0.00 | AvgLoss100 0.0263
# Ep  3650 | Steps  154633 | Score   0 | EpReward -21.19 | Eps 0.153 | AvgScore50 0.00 | AvgLoss100 0.0373
# Ep  3700 | Steps  158297 | Score   0 | EpReward -13.12 | Eps 0.147 | AvgScore50 0.06 | AvgLoss100 0.0338
# Ep  3750 | Steps  161446 | Score   0 | EpReward -21.61 | Eps 0.142 | AvgScore50 0.00 | AvgLoss100 0.0378
# Ep  3800 | Steps  164679 | Score   0 | EpReward -19.79 | Eps 0.136 | AvgScore50 0.00 | AvgLoss100 0.0435
# Ep  3850 | Steps  168552 | Score   0 | EpReward -21.18 | Eps 0.130 | AvgScore50 0.04 | AvgLoss100 0.0651
# Ep  3900 | Steps  172278 | Score   0 | EpReward -12.11 | Eps 0.125 | AvgScore50 0.00 | AvgLoss100 0.0732
# Ep  3950 | Steps  175489 | Score   0 | EpReward -28.66 | Eps 0.120 | AvgScore50 0.02 | AvgLoss100 0.0531
# Ep  4000 | Steps  179041 | Score   0 | EpReward -14.65 | Eps 0.116 | AvgScore50 0.02 | AvgLoss100 0.0837
# Ep  4050 | Steps  183088 | Score   0 | EpReward -26.47 | Eps 0.110 | AvgScore50 0.04 | AvgLoss100 0.0883
# Ep  4100 | Steps  187121 | Score   0 | EpReward -22.85 | Eps 0.105 | AvgScore50 0.06 | AvgLoss100 0.0757
# Ep  4150 | Steps  190807 | Score   0 | EpReward -32.21 | Eps 0.101 | AvgScore50 0.04 | AvgLoss100 0.0910
# Ep  4200 | Steps  194422 | Score   0 | EpReward -16.11 | Eps 0.097 | AvgScore50 0.00 | AvgLoss100 0.1006
# Ep  4250 | Steps  198532 | Score   0 | EpReward  -8.16 | Eps 0.093 | AvgScore50 0.04 | AvgLoss100 0.0765
# Ep  4300 | Steps  202920 | Score   0 | EpReward  -5.52 | Eps 0.088 | AvgScore50 0.10 | AvgLoss100 0.0758
# Ep  4350 | Steps  206949 | Score   0 | EpReward -18.77 | Eps 0.085 | AvgScore50 0.08 | AvgLoss100 0.0760
# Ep  4400 | Steps  211665 | Score   0 | EpReward -21.02 | Eps 0.080 | AvgScore50 0.14 | AvgLoss100 0.0951
# Ep  4450 | Steps  215977 | Score   0 | EpReward -36.28 | Eps 0.077 | AvgScore50 0.06 | AvgLoss100 0.0753
# Ep  4500 | Steps  220775 | Score   0 | EpReward -28.75 | Eps 0.073 | AvgScore50 0.12 | AvgLoss100 0.0611
# Ep  4550 | Steps  225338 | Score   0 | EpReward  -8.21 | Eps 0.069 | AvgScore50 0.14 | AvgLoss100 0.0577
# Ep  4600 | Steps  230867 | Score   0 | EpReward -21.90 | Eps 0.065 | AvgScore50 0.36 | AvgLoss100 0.0537
# Ep  4650 | Steps  235898 | Score   0 | EpReward -24.15 | Eps 0.062 | AvgScore50 0.28 | AvgLoss100 0.0564
# Ep  4700 | Steps  241610 | Score   0 | EpReward  -4.86 | Eps 0.058 | AvgScore50 0.38 | AvgLoss100 0.0576
# Ep  4750 | Steps  246622 | Score   0 | EpReward -13.75 | Eps 0.055 | AvgScore50 0.16 | AvgLoss100 0.0546
# Ep  4800 | Steps  251736 | Score   0 | EpReward  -5.82 | Eps 0.053 | AvgScore50 0.28 | AvgLoss100 0.0530
# Ep  4850 | Steps  257284 | Score   0 | EpReward  -9.24 | Eps 0.050 | AvgScore50 0.30 | AvgLoss100 0.0524
# Ep  4900 | Steps  263737 | Score   1 | EpReward   9.39 | Eps 0.047 | AvgScore50 0.46 | AvgLoss100 0.0594
# Ep  4950 | Steps  269798 | Score   2 | EpReward   5.54 | Eps 0.044 | AvgScore50 0.42 | AvgLoss100 0.0673
# Ep  5000 | Steps  276496 | Score   1 | EpReward   2.60 | Eps 0.041 | AvgScore50 0.46 | AvgLoss100 0.0603
# Ep  5050 | Steps  283089 | Score   0 | EpReward  -8.69 | Eps 0.039 | AvgScore50 0.48 | AvgLoss100 0.0628
# Ep  5100 | Steps  290342 | Score   0 | EpReward  -5.18 | Eps 0.036 | AvgScore50 0.68 | AvgLoss100 0.0714
# Ep  5150 | Steps  297667 | Score   0 | EpReward -11.27 | Eps 0.034 | AvgScore50 0.66 | AvgLoss100 0.0729
# Ep  5200 | Steps  305546 | Score   0 | EpReward -16.63 | Eps 0.032 | AvgScore50 0.76 | AvgLoss100 0.0875
# Ep  5250 | Steps  312542 | Score   0 | EpReward  -6.23 | Eps 0.030 | AvgScore50 0.56 | AvgLoss100 0.1005
# Ep  5300 | Steps  320187 | Score   1 | EpReward   0.71 | Eps 0.028 | AvgScore50 0.66 | AvgLoss100 0.0986
# Ep  5350 | Steps  329499 | Score   1 | EpReward  -2.46 | Eps 0.026 | AvgScore50 1.14 | AvgLoss100 0.1013
# Ep  5400 | Steps  338336 | Score   0 | EpReward  -7.64 | Eps 0.024 | AvgScore50 1.02 | AvgLoss100 0.0949
# Ep  5450 | Steps  346776 | Score   0 | EpReward  -7.97 | Eps 0.023 | AvgScore50 1.00 | AvgLoss100 0.1054
# Ep  5500 | Steps  356324 | Score   3 | EpReward  25.06 | Eps 0.022 | AvgScore50 1.18 | AvgLoss100 0.0859
# Ep  5550 | Steps  365193 | Score   0 | EpReward  -6.99 | Eps 0.020 | AvgScore50 0.94 | AvgLoss100 0.1246
# Ep  5600 | Steps  376535 | Score   0 | EpReward  -9.60 | Eps 0.019 | AvgScore50 1.62 | AvgLoss100 0.1290
# Ep  5650 | Steps  387459 | Score   3 | EpReward  23.60 | Eps 0.018 | AvgScore50 1.52 | AvgLoss100 0.0969
# Ep  5700 | Steps  399277 | Score   1 | EpReward  11.27 | Eps 0.017 | AvgScore50 1.68 | AvgLoss100 0.1203
# Ep  5750 | Steps  411055 | Score   1 | EpReward   7.37 | Eps 0.016 | AvgScore50 1.68 | AvgLoss100 0.1224
# Ep  5800 | Steps  421572 | Score   0 | EpReward  -9.17 | Eps 0.015 | AvgScore50 1.38 | AvgLoss100 0.1592
# Ep  5850 | Steps  428958 | Score   0 | EpReward  -9.28 | Eps 0.015 | AvgScore50 0.66 | AvgLoss100 0.1159
# Ep  5900 | Steps  435068 | Score   0 | EpReward  -4.25 | Eps 0.014 | AvgScore50 0.46 | AvgLoss100 0.1425
# Ep  5950 | Steps  444484 | Score   2 | EpReward  27.23 | Eps 0.014 | AvgScore50 1.14 | AvgLoss100 0.1502
# Ep  6000 | Steps  458500 | Score   5 | EpReward  51.62 | Eps 0.013 | AvgScore50 2.28 | AvgLoss100 0.1472
# Ep  6050 | Steps  467420 | Score   1 | EpReward   9.21 | Eps 0.013 | AvgScore50 1.08 | AvgLoss100 0.1323
# Ep  6100 | Steps  476689 | Score   1 | EpReward   6.33 | Eps 0.013 | AvgScore50 1.08 | AvgLoss100 0.1563
# Ep  6150 | Steps  485782 | Score   0 | EpReward  -7.39 | Eps 0.012 | AvgScore50 1.04 | AvgLoss100 0.1295
# Ep  6200 | Steps  496733 | Score   0 | EpReward  -4.02 | Eps 0.012 | AvgScore50 1.42 | AvgLoss100 0.1560
# Ep  6250 | Steps  508153 | Score   0 | EpReward -10.58 | Eps 0.012 | AvgScore50 1.62 | AvgLoss100 0.1636
# Ep  6300 | Steps  518583 | Score   1 | EpReward -11.11 | Eps 0.012 | AvgScore50 1.54 | AvgLoss100 0.1692
# Ep  6350 | Steps  526584 | Score   2 | EpReward  19.09 | Eps 0.011 | AvgScore50 1.00 | AvgLoss100 0.1622
# Ep  6400 | Steps  536335 | Score   1 | EpReward -14.05 | Eps 0.011 | AvgScore50 1.26 | AvgLoss100 0.1580
# Ep  6450 | Steps  553017 | Score   8 | EpReward 106.87 | Eps 0.011 | AvgScore50 2.72 | AvgLoss100 0.1903
# Ep  6500 | Steps  564854 | Score   1 | EpReward  -5.14 | Eps 0.011 | AvgScore50 1.68 | AvgLoss100 0.1655
# Ep  6550 | Steps  574217 | Score   2 | EpReward  22.24 | Eps 0.011 | AvgScore50 1.06 | AvgLoss100 0.1621
# Ep  6600 | Steps  580834 | Score   1 | EpReward   5.82 | Eps 0.011 | AvgScore50 0.56 | AvgLoss100 0.2009
# Ep  6650 | Steps  589153 | Score   0 | EpReward  -8.71 | Eps 0.011 | AvgScore50 1.08 | AvgLoss100 0.1834
# Ep  6700 | Steps  596582 | Score   1 | EpReward   3.35 | Eps 0.011 | AvgScore50 1.06 | AvgLoss100 0.1728
# Ep  6750 | Steps  603398 | Score   0 | EpReward  -9.48 | Eps 0.011 | AvgScore50 0.82 | AvgLoss100 0.1465
# Ep  6800 | Steps  612122 | Score   1 | EpReward  11.44 | Eps 0.010 | AvgScore50 1.12 | AvgLoss100 0.1657
# Ep  6850 | Steps  625509 | Score   3 | EpReward  30.30 | Eps 0.010 | AvgScore50 2.02 | AvgLoss100 0.2021
# Ep  6900 | Steps  640828 | Score   3 | EpReward  36.37 | Eps 0.010 | AvgScore50 2.66 | AvgLoss100 0.2231
# Ep  6950 | Steps  649836 | Score   0 | EpReward  -4.61 | Eps 0.010 | AvgScore50 0.92 | AvgLoss100 0.2325
# Ep  7000 | Steps  661571 | Score   2 | EpReward  21.42 | Eps 0.010 | AvgScore50 1.58 | AvgLoss100 0.1790
# Ep  7050 | Steps  677372 | Score   2 | EpReward  21.86 | Eps 0.010 | AvgScore50 2.56 | AvgLoss100 0.1851
# Ep  7100 | Steps  691740 | Score   0 | EpReward  -6.50 | Eps 0.010 | AvgScore50 2.20 | AvgLoss100 0.1701
# Ep  7150 | Steps  700999 | Score   1 | EpReward   2.06 | Eps 0.010 | AvgScore50 1.10 | AvgLoss100 0.2064
# Ep  7200 | Steps  710074 | Score   2 | EpReward  21.48 | Eps 0.010 | AvgScore50 1.04 | AvgLoss100 0.2182
# Ep  7250 | Steps  720856 | Score   1 | EpReward   2.50 | Eps 0.010 | AvgScore50 1.52 | AvgLoss100 0.1323
# Ep  7300 | Steps  730581 | Score   0 | EpReward  -7.93 | Eps 0.010 | AvgScore50 1.20 | AvgLoss100 0.1488
# Ep  7350 | Steps  743524 | Score   5 | EpReward  60.39 | Eps 0.010 | AvgScore50 1.98 | AvgLoss100 0.1998
# Ep  7400 | Steps  756987 | Score   9 | EpReward 109.05 | Eps 0.010 | AvgScore50 2.20 | AvgLoss100 0.1844
# Ep  7450 | Steps  769121 | Score   1 | EpReward  10.97 | Eps 0.010 | AvgScore50 1.90 | AvgLoss100 0.1662
# Ep  7500 | Steps  780652 | Score   1 | EpReward  11.82 | Eps 0.010 | AvgScore50 1.70 | AvgLoss100 0.2027
# Ep  7550 | Steps  791248 | Score   2 | EpReward  12.34 | Eps 0.010 | AvgScore50 1.50 | AvgLoss100 0.1792
# Ep  7600 | Steps  801984 | Score   3 | EpReward  42.21 | Eps 0.010 | AvgScore50 1.44 | AvgLoss100 0.2055
# Ep  7650 | Steps  812581 | Score   0 | EpReward  -6.83 | Eps 0.010 | AvgScore50 1.40 | AvgLoss100 0.1830
# Ep  7700 | Steps  826023 | Score   1 | EpReward   6.16 | Eps 0.010 | AvgScore50 2.06 | AvgLoss100 0.2004
# Ep  7750 | Steps  832757 | Score   1 | EpReward   2.76 | Eps 0.010 | AvgScore50 0.48 | AvgLoss100 0.1918
# Ep  7800 | Steps  837810 | Score   0 | EpReward  -6.12 | Eps 0.010 | AvgScore50 0.12 | AvgLoss100 0.1886
# Ep  7850 | Steps  843072 | Score   0 | EpReward  -7.75 | Eps 0.010 | AvgScore50 0.18 | AvgLoss100 0.1850
# Ep  7900 | Steps  849124 | Score   0 | EpReward -10.50 | Eps 0.010 | AvgScore50 0.38 | AvgLoss100 0.2093
# Ep  7950 | Steps  865113 | Score   6 | EpReward  60.95 | Eps 0.010 | AvgScore50 2.62 | AvgLoss100 0.2047
# Ep  8000 | Steps  877418 | Score   2 | EpReward   6.13 | Eps 0.010 | AvgScore50 1.78 | AvgLoss100 0.2410
# Ep  8050 | Steps  891950 | Score   0 | EpReward  -7.45 | Eps 0.010 | AvgScore50 2.40 | AvgLoss100 0.2584
# Ep  8100 | Steps  900321 | Score   0 | EpReward -18.58 | Eps 0.010 | AvgScore50 1.16 | AvgLoss100 0.2236
# Ep  8150 | Steps  910948 | Score   0 | EpReward  -6.77 | Eps 0.010 | AvgScore50 1.56 | AvgLoss100 0.2084
# Ep  8200 | Steps  921366 | Score   0 | EpReward  -9.44 | Eps 0.010 | AvgScore50 1.32 | AvgLoss100 0.2148
# Ep  8250 | Steps  932675 | Score   1 | EpReward  -0.26 | Eps 0.010 | AvgScore50 1.56 | AvgLoss100 0.2182
# Ep  8300 | Steps  944769 | Score   2 | EpReward  15.69 | Eps 0.010 | AvgScore50 1.70 | AvgLoss100 0.2122
# Ep  8350 | Steps  958834 | Score   1 | EpReward  -2.33 | Eps 0.010 | AvgScore50 2.18 | AvgLoss100 0.2316
# Ep  8400 | Steps  969031 | Score   0 | EpReward  -6.76 | Eps 0.010 | AvgScore50 1.44 | AvgLoss100 0.2148
# Ep  8450 | Steps  980263 | Score   3 | EpReward  26.75 | Eps 0.010 | AvgScore50 1.46 | AvgLoss100 0.1719
# Ep  8500 | Steps  993146 | Score   9 | EpReward  85.59 | Eps 0.010 | AvgScore50 1.86 | AvgLoss100 0.1608
# Ep  8550 | Steps 1008020 | Score   1 | EpReward   4.10 | Eps 0.010 | AvgScore50 2.34 | AvgLoss100 0.2009
# Ep  8600 | Steps 1021415 | Score   0 | EpReward  -9.20 | Eps 0.010 | AvgScore50 2.14 | AvgLoss100 0.2095
# Ep  8650 | Steps 1029336 | Score   0 | EpReward  -6.03 | Eps 0.010 | AvgScore50 0.88 | AvgLoss100 0.1712
# Ep  8700 | Steps 1035059 | Score   0 | EpReward  -8.97 | Eps 0.010 | AvgScore50 0.40 | AvgLoss100 0.2137
# Ep  8750 | Steps 1042242 | Score   0 | EpReward  -6.98 | Eps 0.010 | AvgScore50 0.58 | AvgLoss100 0.2080
# Ep  8800 | Steps 1050347 | Score   1 | EpReward   7.01 | Eps 0.010 | AvgScore50 0.72 | AvgLoss100 0.2922
# Ep  8850 | Steps 1058743 | Score   1 | EpReward  12.70 | Eps 0.010 | AvgScore50 0.84 | AvgLoss100 0.2040
# Ep  8900 | Steps 1068237 | Score   1 | EpReward  -3.19 | Eps 0.010 | AvgScore50 1.06 | AvgLoss100 0.2199
# Ep  8950 | Steps 1078520 | Score   3 | EpReward  29.26 | Eps 0.010 | AvgScore50 1.30 | AvgLoss100 0.2134
# Ep  9000 | Steps 1092774 | Score   4 | EpReward  30.66 | Eps 0.010 | AvgScore50 2.12 | AvgLoss100 0.2699
# Ep  9050 | Steps 1101086 | Score   0 | EpReward -11.50 | Eps 0.010 | AvgScore50 0.92 | AvgLoss100 0.2430
# Ep  9100 | Steps 1109243 | Score   3 | EpReward  29.91 | Eps 0.010 | AvgScore50 0.80 | AvgLoss100 0.2343
# Ep  9150 | Steps 1125312 | Score   1 | EpReward   5.70 | Eps 0.010 | AvgScore50 2.56 | AvgLoss100 0.2279
# Ep  9200 | Steps 1142457 | Score   0 | EpReward -14.09 | Eps 0.010 | AvgScore50 2.88 | AvgLoss100 0.2289
# Ep  9250 | Steps 1159088 | Score   0 | EpReward  -9.32 | Eps 0.010 | AvgScore50 2.80 | AvgLoss100 0.1297
# Ep  9300 | Steps 1175878 | Score   1 | EpReward   3.14 | Eps 0.010 | AvgScore50 2.84 | AvgLoss100 0.1854
# Ep  9350 | Steps 1189490 | Score   6 | EpReward  64.73 | Eps 0.010 | AvgScore50 2.24 | AvgLoss100 0.1927
# Ep  9400 | Steps 1200759 | Score   0 | EpReward  -4.12 | Eps 0.010 | AvgScore50 1.64 | AvgLoss100 0.1884
# Ep  9450 | Steps 1211838 | Score   4 | EpReward  48.98 | Eps 0.010 | AvgScore50 1.52 | AvgLoss100 0.1897
# Ep  9500 | Steps 1223568 | Score   0 | EpReward -16.23 | Eps 0.010 | AvgScore50 1.62 | AvgLoss100 0.1920
# Ep  9550 | Steps 1232848 | Score   0 | EpReward  -5.35 | Eps 0.010 | AvgScore50 1.02 | AvgLoss100 0.1973
# Ep  9600 | Steps 1247170 | Score   3 | EpReward  32.90 | Eps 0.010 | AvgScore50 2.26 | AvgLoss100 0.1797
# Ep  9650 | Steps 1260717 | Score   1 | EpReward   6.06 | Eps 0.010 | AvgScore50 2.20 | AvgLoss100 0.1924
# Ep  9700 | Steps 1273687 | Score   2 | EpReward  21.65 | Eps 0.010 | AvgScore50 1.98 | AvgLoss100 0.1766
# Ep  9750 | Steps 1292436 | Score   2 | EpReward  17.94 | Eps 0.010 | AvgScore50 3.32 | AvgLoss100 0.1569
# Ep  9800 | Steps 1308528 | Score  12 | EpReward 161.40 | Eps 0.010 | AvgScore50 2.74 | AvgLoss100 0.1394
# Ep  9850 | Steps 1321318 | Score   0 | EpReward  -9.08 | Eps 0.010 | AvgScore50 1.82 | AvgLoss100 0.1339
# Ep  9900 | Steps 1329132 | Score   0 | EpReward  -4.30 | Eps 0.010 | AvgScore50 0.58 | AvgLoss100 0.2019
# Ep  9950 | Steps 1336808 | Score   1 | EpReward  10.86 | Eps 0.010 | AvgScore50 0.56 | AvgLoss100 0.1994
# Ep 10000 | Steps 1343742 | Score   1 | EpReward   7.09 | Eps 0.010 | AvgScore50 0.40 | AvgLoss100 0.1959
# Ep 10050 | Steps 1350227 | Score   0 | EpReward  -4.83 | Eps 0.010 | AvgScore50 0.44 | AvgLoss100 0.1803
# Ep 10100 | Steps 1362864 | Score   2 | EpReward -35.98 | Eps 0.010 | AvgScore50 1.86 | AvgLoss100 0.1953
# Ep 10150 | Steps 1376249 | Score   3 | EpReward  22.89 | Eps 0.010 | AvgScore50 2.24 | AvgLoss100 0.2064
# Ep 10200 | Steps 1388514 | Score   3 | EpReward  33.52 | Eps 0.010 | AvgScore50 1.86 | AvgLoss100 0.2410
# Ep 10250 | Steps 1402402 | Score   3 | EpReward  23.66 | Eps 0.010 | AvgScore50 2.24 | AvgLoss100 0.2149
# Ep 10300 | Steps 1418358 | Score   3 | EpReward  16.56 | Eps 0.010 | AvgScore50 2.62 | AvgLoss100 0.1841
# Ep 10350 | Steps 1429336 | Score   2 | EpReward  19.94 | Eps 0.010 | AvgScore50 1.52 | AvgLoss100 0.1781
# Ep 10400 | Steps 1441506 | Score   0 | EpReward  -9.09 | Eps 0.010 | AvgScore50 1.74 | AvgLoss100 0.1781
# Ep 10450 | Steps 1453805 | Score   2 | EpReward  25.99 | Eps 0.010 | AvgScore50 1.76 | AvgLoss100 0.2132
# Ep 10500 | Steps 1468906 | Score   1 | EpReward   3.66 | Eps 0.010 | AvgScore50 2.60 | AvgLoss100 0.2450
# Ep 10550 | Steps 1480341 | Score   0 | EpReward  -9.55 | Eps 0.010 | AvgScore50 1.76 | AvgLoss100 0.2487
# Ep 10600 | Steps 1487442 | Score   0 | EpReward  -4.07 | Eps 0.010 | AvgScore50 0.70 | AvgLoss100 0.2681
# Ep 10650 | Steps 1492238 | Score   0 | EpReward  -7.42 | Eps 0.010 | AvgScore50 0.26 | AvgLoss100 0.2529
# Ep 10700 | Steps 1497888 | Score   1 | EpReward   0.73 | Eps 0.010 | AvgScore50 0.30 | AvgLoss100 0.3195
# Ep 10750 | Steps 1504400 | Score   0 | EpReward  -9.26 | Eps 0.010 | AvgScore50 0.44 | AvgLoss100 0.2369
# Ep 10800 | Steps 1512719 | Score   1 | EpReward -12.13 | Eps 0.010 | AvgScore50 0.78 | AvgLoss100 0.2379
# Ep 10850 | Steps 1522076 | Score   0 | EpReward -16.14 | Eps 0.010 | AvgScore50 1.24 | AvgLoss100 0.2873
# Ep 10900 | Steps 1529371 | Score   6 | EpReward  74.36 | Eps 0.010 | AvgScore50 0.92 | AvgLoss100 0.2985
# Ep 10950 | Steps 1537325 | Score   3 | EpReward  30.53 | Eps 0.010 | AvgScore50 0.84 | AvgLoss100 0.2998
# Ep 11000 | Steps 1548601 | Score   2 | EpReward   6.44 | Eps 0.010 | AvgScore50 1.66 | AvgLoss100 0.3360
# Ep 11050 | Steps 1561275 | Score   1 | EpReward   7.39 | Eps 0.010 | AvgScore50 2.02 | AvgLoss100 0.3181
# Ep 11100 | Steps 1575412 | Score   0 | EpReward  -7.83 | Eps 0.010 | AvgScore50 2.44 | AvgLoss100 0.3070
# Ep 11150 | Steps 1584653 | Score   0 | EpReward -10.61 | Eps 0.010 | AvgScore50 1.48 | AvgLoss100 0.2930
# Ep 11200 | Steps 1595305 | Score   0 | EpReward -20.18 | Eps 0.010 | AvgScore50 1.60 | AvgLoss100 0.2485
# Ep 11250 | Steps 1601865 | Score   1 | EpReward   6.47 | Eps 0.010 | AvgScore50 0.54 | AvgLoss100 0.2552
# Ep 11300 | Steps 1607524 | Score   0 | EpReward  -9.64 | Eps 0.010 | AvgScore50 0.28 | AvgLoss100 0.2139
# Ep 11350 | Steps 1615277 | Score   1 | EpReward  -4.73 | Eps 0.010 | AvgScore50 0.74 | AvgLoss100 0.2095
# Ep 11400 | Steps 1630061 | Score   3 | EpReward  37.61 | Eps 0.010 | AvgScore50 2.40 | AvgLoss100 0.2225
# Ep 11450 | Steps 1644066 | Score   1 | EpReward  -3.86 | Eps 0.010 | AvgScore50 2.26 | AvgLoss100 0.2230
# Ep 11500 | Steps 1654378 | Score   1 | EpReward  -2.17 | Eps 0.010 | AvgScore50 1.42 | AvgLoss100 0.2225
# Ep 11550 | Steps 1660892 | Score   1 | EpReward   8.63 | Eps 0.010 | AvgScore50 0.42 | AvgLoss100 0.2480
# Ep 11600 | Steps 1667751 | Score   0 | EpReward  -8.75 | Eps 0.010 | AvgScore50 0.44 | AvgLoss100 0.2429
# Ep 11650 | Steps 1675294 | Score   0 | EpReward  -8.05 | Eps 0.010 | AvgScore50 0.64 | AvgLoss100 0.2432
# Ep 11700 | Steps 1681922 | Score   2 | EpReward  12.93 | Eps 0.010 | AvgScore50 0.48 | AvgLoss100 0.2435
# Ep 11750 | Steps 1695618 | Score   0 | EpReward  -7.55 | Eps 0.010 | AvgScore50 2.18 | AvgLoss100 0.2725
# Ep 11800 | Steps 1711305 | Score   7 | EpReward  69.58 | Eps 0.010 | AvgScore50 2.52 | AvgLoss100 0.1910
# Ep 11850 | Steps 1727056 | Score   2 | EpReward   7.77 | Eps 0.010 | AvgScore50 2.58 | AvgLoss100 0.2353
# Ep 11900 | Steps 1741821 | Score   2 | EpReward  14.64 | Eps 0.010 | AvgScore50 2.48 | AvgLoss100 0.1761
# Ep 11950 | Steps 1756104 | Score   1 | EpReward  -3.58 | Eps 0.010 | AvgScore50 2.36 | AvgLoss100 0.1932
# Ep 12000 | Steps 1769440 | Score   3 | EpReward  26.34 | Eps 0.010 | AvgScore50 2.08 | AvgLoss100 0.1607
# Ep 12050 | Steps 1782886 | Score   0 | EpReward  -9.09 | Eps 0.010 | AvgScore50 2.30 | AvgLoss100 0.1390
# Ep 12100 | Steps 1789436 | Score   1 | EpReward   2.82 | Eps 0.010 | AvgScore50 0.58 | AvgLoss100 0.1601
# Ep 12150 | Steps 1797310 | Score   1 | EpReward  -4.26 | Eps 0.010 | AvgScore50 0.90 | AvgLoss100 0.1506
# Ep 12200 | Steps 1809451 | Score   0 | EpReward -10.16 | Eps 0.010 | AvgScore50 1.98 | AvgLoss100 0.1523
# Ep 12250 | Steps 1822889 | Score   1 | EpReward   8.91 | Eps 0.010 | AvgScore50 2.24 | AvgLoss100 0.1516
# Ep 12300 | Steps 1832152 | Score   1 | EpReward -11.38 | Eps 0.010 | AvgScore50 1.10 | AvgLoss100 0.1679
# Ep 12350 | Steps 1840962 | Score   1 | EpReward  -4.65 | Eps 0.010 | AvgScore50 0.96 | AvgLoss100 0.1786
# Ep 12400 | Steps 1848775 | Score   0 | EpReward  -4.63 | Eps 0.010 | AvgScore50 0.72 | AvgLoss100 0.1714
# Ep 12450 | Steps 1857869 | Score   0 | EpReward  -4.70 | Eps 0.010 | AvgScore50 0.98 | AvgLoss100 0.2273
# Ep 12500 | Steps 1867595 | Score   1 | EpReward  -0.18 | Eps 0.010 | AvgScore50 1.04 | AvgLoss100 0.2408
# Ep 12550 | Steps 1875429 | Score   0 | EpReward  -6.82 | Eps 0.010 | AvgScore50 0.74 | AvgLoss100 0.2415
# Ep 12600 | Steps 1884753 | Score   3 | EpReward  33.03 | Eps 0.010 | AvgScore50 1.08 | AvgLoss100 0.1674
# Ep 12650 | Steps 1894955 | Score   0 | EpReward  -4.55 | Eps 0.010 | AvgScore50 1.38 | AvgLoss100 0.2252
# Ep 12700 | Steps 1904476 | Score   0 | EpReward  -7.80 | Eps 0.010 | AvgScore50 1.10 | AvgLoss100 0.1876
# Ep 12750 | Steps 1914194 | Score   1 | EpReward   5.33 | Eps 0.010 | AvgScore50 1.20 | AvgLoss100 0.1937
# Ep 12800 | Steps 1922832 | Score   4 | EpReward  50.33 | Eps 0.010 | AvgScore50 0.90 | AvgLoss100 0.2211
# Ep 12850 | Steps 1934053 | Score   0 | EpReward -11.23 | Eps 0.010 | AvgScore50 1.66 | AvgLoss100 0.2014
# Ep 12900 | Steps 1945539 | Score   0 | EpReward  -5.48 | Eps 0.010 | AvgScore50 1.76 | AvgLoss100 0.2330
# Ep 12950 | Steps 1959800 | Score   1 | EpReward  -8.54 | Eps 0.010 | AvgScore50 2.18 | AvgLoss100 0.2555
# Ep 13000 | Steps 1975323 | Score   5 | EpReward   6.17 | Eps 0.010 | AvgScore50 2.48 | AvgLoss100 0.2192
# Ep 13050 | Steps 1988139 | Score   2 | EpReward  15.09 | Eps 0.010 | AvgScore50 1.80 | AvgLoss100 0.1877
# Ep 13100 | Steps 2000824 | Score   4 | EpReward  22.19 | Eps 0.010 | AvgScore50 2.06 | AvgLoss100 0.1881
# Ep 13150 | Steps 2017015 | Score   8 | EpReward  77.40 | Eps 0.010 | AvgScore50 2.82 | AvgLoss100 0.1511
# Ep 13200 | Steps 2034150 | Score   8 | EpReward  83.58 | Eps 0.010 | AvgScore50 3.06 | AvgLoss100 0.1570
# Ep 13250 | Steps 2045740 | Score   2 | EpReward  21.69 | Eps 0.010 | AvgScore50 1.82 | AvgLoss100 0.1432
# Ep 13300 | Steps 2057763 | Score   0 | EpReward  -9.52 | Eps 0.010 | AvgScore50 1.74 | AvgLoss100 0.1536
# Ep 13350 | Steps 2067973 | Score   3 | EpReward  35.75 | Eps 0.010 | AvgScore50 1.26 | AvgLoss100 0.1426
# Ep 13400 | Steps 2077643 | Score   1 | EpReward  -0.50 | Eps 0.010 | AvgScore50 1.06 | AvgLoss100 0.1983
# Ep 13450 | Steps 2086183 | Score   0 | EpReward  -3.77 | Eps 0.010 | AvgScore50 0.84 | AvgLoss100 0.1805
# Ep 13500 | Steps 2096220 | Score   4 | EpReward  34.08 | Eps 0.010 | AvgScore50 1.28 | AvgLoss100 0.1626
# Ep 13550 | Steps 2110304 | Score   0 | EpReward  -8.37 | Eps 0.010 | AvgScore50 2.40 | AvgLoss100 0.1642
# Ep 13600 | Steps 2120150 | Score   0 | EpReward  -8.46 | Eps 0.010 | AvgScore50 1.50 | AvgLoss100 0.2167
# Ep 13650 | Steps 2128940 | Score   0 | EpReward -11.56 | Eps 0.010 | AvgScore50 0.96 | AvgLoss100 0.1933
# Ep 13700 | Steps 2135842 | Score   0 | EpReward  -3.81 | Eps 0.010 | AvgScore50 0.42 | AvgLoss100 0.1854
# Ep 13750 | Steps 2141709 | Score   0 | EpReward -11.03 | Eps 0.010 | AvgScore50 0.18 | AvgLoss100 0.1859
# Ep 13800 | Steps 2148571 | Score   0 | EpReward  -5.62 | Eps 0.010 | AvgScore50 0.40 | AvgLoss100 0.2195
# Ep 13850 | Steps 2154773 | Score   1 | EpReward   7.66 | Eps 0.010 | AvgScore50 0.30 | AvgLoss100 0.2730
# Ep 13900 | Steps 2162911 | Score   1 | EpReward -12.11 | Eps 0.010 | AvgScore50 0.78 | AvgLoss100 0.2849
# Ep 13950 | Steps 2178763 | Score   0 | EpReward  -8.89 | Eps 0.010 | AvgScore50 2.82 | AvgLoss100 0.2336
# Ep 14000 | Steps 2195726 | Score   1 | EpReward  10.30 | Eps 0.010 | AvgScore50 2.94 | AvgLoss100 0.1728
# Ep 14050 | Steps 2210794 | Score   2 | EpReward  13.01 | Eps 0.010 | AvgScore50 2.32 | AvgLoss100 0.1947
# Ep 14100 | Steps 2227245 | Score   2 | EpReward  18.56 | Eps 0.010 | AvgScore50 2.72 | AvgLoss100 0.2082
# Ep 14150 | Steps 2243862 | Score  13 | EpReward 147.32 | Eps 0.010 | AvgScore50 2.76 | AvgLoss100 0.1634
# Ep 14200 | Steps 2258775 | Score   8 | EpReward  99.21 | Eps 0.010 | AvgScore50 2.34 | AvgLoss100 0.1437
# Ep 14250 | Steps 2271416 | Score   0 | EpReward  -6.57 | Eps 0.010 | AvgScore50 1.92 | AvgLoss100 0.1452
# Ep 14300 | Steps 2290225 | Score   5 | EpReward  48.14 | Eps 0.010 | AvgScore50 3.18 | AvgLoss100 0.1338
# Ep 14350 | Steps 2303419 | Score   0 | EpReward  -7.28 | Eps 0.010 | AvgScore50 2.08 | AvgLoss100 0.1415
# Ep 14400 | Steps 2313709 | Score   0 | EpReward -22.63 | Eps 0.010 | AvgScore50 1.36 | AvgLoss100 0.1653
# Ep 14450 | Steps 2324783 | Score   9 | EpReward 100.31 | Eps 0.010 | AvgScore50 1.56 | AvgLoss100 0.1796
# Ep 14500 | Steps 2343782 | Score   4 | EpReward  58.94 | Eps 0.010 | AvgScore50 3.34 | AvgLoss100 0.1666
# Ep 14550 | Steps 2359367 | Score   2 | EpReward  19.61 | Eps 0.010 | AvgScore50 2.62 | AvgLoss100 0.1685
# Ep 14600 | Steps 2370222 | Score   1 | EpReward   9.67 | Eps 0.010 | AvgScore50 1.48 | AvgLoss100 0.1667
# Ep 14650 | Steps 2378779 | Score   1 | EpReward  10.05 | Eps 0.010 | AvgScore50 0.90 | AvgLoss100 0.2073
# Ep 14700 | Steps 2390509 | Score   0 | EpReward  -4.96 | Eps 0.010 | AvgScore50 1.60 | AvgLoss100 0.2129
# Ep 14750 | Steps 2402228 | Score   0 | EpReward -10.06 | Eps 0.010 | AvgScore50 1.66 | AvgLoss100 0.1989
# Ep 14800 | Steps 2417705 | Score   3 | EpReward  34.69 | Eps 0.010 | AvgScore50 2.58 | AvgLoss100 0.1673
# Ep 14850 | Steps 2434490 | Score   8 | EpReward  84.22 | Eps 0.010 | AvgScore50 2.76 | AvgLoss100 0.2352
# Ep 14900 | Steps 2447487 | Score   1 | EpReward   5.44 | Eps 0.010 | AvgScore50 2.00 | AvgLoss100 0.1791
# Ep 14950 | Steps 2461308 | Score   5 | EpReward  41.71 | Eps 0.010 | AvgScore50 2.10 | AvgLoss100 0.1957
# Ep 15000 | Steps 2476448 | Score   4 | EpReward  36.52 | Eps 0.010 | AvgScore50 2.46 | AvgLoss100 0.2069
# Ep 15050 | Steps 2493896 | Score   1 | EpReward   1.32 | Eps 0.010 | AvgScore50 2.82 | AvgLoss100 0.1487
# Ep 15100 | Steps 2509810 | Score   0 | EpReward -10.42 | Eps 0.010 | AvgScore50 2.72 | AvgLoss100 0.1402
# Ep 15150 | Steps 2518186 | Score   1 | EpReward   5.10 | Eps 0.010 | AvgScore50 1.10 | AvgLoss100 0.1596
# Ep 15200 | Steps 2528485 | Score   2 | EpReward  17.02 | Eps 0.010 | AvgScore50 1.50 | AvgLoss100 0.1836
# Ep 15250 | Steps 2536703 | Score   1 | EpReward   9.60 | Eps 0.010 | AvgScore50 1.10 | AvgLoss100 0.1879
# Ep 15300 | Steps 2546617 | Score   0 | EpReward  -6.15 | Eps 0.010 | AvgScore50 1.46 | AvgLoss100 0.1807
# Ep 15350 | Steps 2557964 | Score   4 | EpReward  42.77 | Eps 0.010 | AvgScore50 1.80 | AvgLoss100 0.1971
# Ep 15400 | Steps 2570057 | Score   2 | EpReward   6.66 | Eps 0.010 | AvgScore50 1.82 | AvgLoss100 0.2190
# Ep 15450 | Steps 2579216 | Score   1 | EpReward -19.18 | Eps 0.010 | AvgScore50 1.24 | AvgLoss100 0.2063
# Ep 15500 | Steps 2584886 | Score   0 | EpReward -29.95 | Eps 0.010 | AvgScore50 0.54 | AvgLoss100 0.2242
# Ep 15550 | Steps 2588845 | Score   0 | EpReward -19.56 | Eps 0.010 | AvgScore50 0.24 | AvgLoss100 0.1919
# Ep 15600 | Steps 2596136 | Score   1 | EpReward  -0.84 | Eps 0.010 | AvgScore50 0.76 | AvgLoss100 0.1883
# Ep 15650 | Steps 2608447 | Score   7 | EpReward  89.53 | Eps 0.010 | AvgScore50 1.72 | AvgLoss100 0.2060
# Ep 15700 | Steps 2622802 | Score   5 | EpReward  50.32 | Eps 0.010 | AvgScore50 2.34 | AvgLoss100 0.2252
# Ep 15750 | Steps 2637657 | Score   2 | EpReward  20.63 | Eps 0.010 | AvgScore50 2.42 | AvgLoss100 0.1962
# Ep 15800 | Steps 2653418 | Score   7 | EpReward  82.33 | Eps 0.010 | AvgScore50 2.54 | AvgLoss100 0.1525
# Ep 15850 | Steps 2669134 | Score   0 | EpReward  -8.77 | Eps 0.010 | AvgScore50 2.58 | AvgLoss100 0.1569
# Ep 15900 | Steps 2687205 | Score   3 | EpReward  18.86 | Eps 0.010 | AvgScore50 3.08 | AvgLoss100 0.1995
# Ep 15950 | Steps 2702729 | Score   2 | EpReward  -0.62 | Eps 0.010 | AvgScore50 2.68 | AvgLoss100 0.1461
# Ep 16000 | Steps 2714777 | Score   6 | EpReward  58.41 | Eps 0.010 | AvgScore50 1.98 | AvgLoss100 0.1532
# Ep 16050 | Steps 2725899 | Score   3 | EpReward  16.69 | Eps 0.010 | AvgScore50 1.60 | AvgLoss100 0.1813
# Ep 16100 | Steps 2741554 | Score   0 | EpReward  -9.50 | Eps 0.010 | AvgScore50 2.64 | AvgLoss100 0.1776
# Ep 16150 | Steps 2758779 | Score   2 | EpReward  23.98 | Eps 0.010 | AvgScore50 2.88 | AvgLoss100 0.1660
# Ep 16200 | Steps 2774161 | Score   0 | EpReward  -5.61 | Eps 0.010 | AvgScore50 2.56 | AvgLoss100 0.1522
# Ep 16250 | Steps 2789328 | Score   3 | EpReward  32.48 | Eps 0.010 | AvgScore50 2.42 | AvgLoss100 0.1639
# Ep 16300 | Steps 2806408 | Score   4 | EpReward  50.45 | Eps 0.010 | AvgScore50 2.82 | AvgLoss100 0.1714
# Ep 16350 | Steps 2819561 | Score   1 | EpReward  -1.25 | Eps 0.010 | AvgScore50 2.14 | AvgLoss100 0.1379
# Ep 16400 | Steps 2834004 | Score   6 | EpReward  77.08 | Eps 0.010 | AvgScore50 2.32 | AvgLoss100 0.1682
# Ep 16450 | Steps 2847949 | Score   2 | EpReward  19.24 | Eps 0.010 | AvgScore50 2.18 | AvgLoss100 0.1619
# Ep 16500 | Steps 2862139 | Score   1 | EpReward  -2.65 | Eps 0.010 | AvgScore50 2.20 | AvgLoss100 0.1611
# Ep 16550 | Steps 2875656 | Score   1 | EpReward   0.78 | Eps 0.010 | AvgScore50 2.14 | AvgLoss100 0.1225
# Ep 16600 | Steps 2888947 | Score   2 | EpReward  20.97 | Eps 0.010 | AvgScore50 2.08 | AvgLoss100 0.1899
# Ep 16650 | Steps 2902742 | Score   0 | EpReward  -9.09 | Eps 0.010 | AvgScore50 2.12 | AvgLoss100 0.1953
# Ep 16700 | Steps 2915500 | Score   2 | EpReward  20.27 | Eps 0.010 | AvgScore50 1.98 | AvgLoss100 0.1626
# Ep 16750 | Steps 2928847 | Score   0 | EpReward  -4.33 | Eps 0.010 | AvgScore50 2.08 | AvgLoss100 0.1890
# Ep 16800 | Steps 2944523 | Score   3 | EpReward  -6.23 | Eps 0.010 | AvgScore50 2.52 | AvgLoss100 0.1729
# Ep 16850 | Steps 2954963 | Score   1 | EpReward -17.12 | Eps 0.010 | AvgScore50 1.36 | AvgLoss100 0.1765
# Ep 16900 | Steps 2972461 | Score   6 | EpReward  56.16 | Eps 0.010 | AvgScore50 2.88 | AvgLoss100 0.1832
# Ep 16950 | Steps 2985777 | Score   0 | EpReward  -6.44 | Eps 0.010 | AvgScore50 2.02 | AvgLoss100 0.1356
# Ep 17000 | Steps 2999532 | Score   1 | EpReward -14.07 | Eps 0.010 | AvgScore50 2.26 | AvgLoss100 0.1650
# Ep 17050 | Steps 3006019 | Score   0 | EpReward  -8.71 | Eps 0.010 | AvgScore50 0.66 | AvgLoss100 0.2004
# Ep 17100 | Steps 3013214 | Score   0 | EpReward  -5.59 | Eps 0.010 | AvgScore50 0.72 | AvgLoss100 0.2055
# Ep 17150 | Steps 3022794 | Score   5 | EpReward  36.87 | Eps 0.010 | AvgScore50 1.36 | AvgLoss100 0.1988
# Ep 17200 | Steps 3035828 | Score   0 | EpReward -15.94 | Eps 0.010 | AvgScore50 2.08 | AvgLoss100 0.1931
# Ep 17250 | Steps 3054212 | Score   8 | EpReward  68.79 | Eps 0.010 | AvgScore50 3.20 | AvgLoss100 0.1904
# Ep 17300 | Steps 3069162 | Score   1 | EpReward -24.24 | Eps 0.010 | AvgScore50 2.24 | AvgLoss100 0.1685
# Ep 17350 | Steps 3076450 | Score   0 | EpReward  -3.96 | Eps 0.010 | AvgScore50 0.60 | AvgLoss100 0.2077
# Ep 17400 | Steps 3083625 | Score   0 | EpReward  -3.99 | Eps 0.010 | AvgScore50 0.58 | AvgLoss100 0.2010
# Ep 17450 | Steps 3089648 | Score   0 | EpReward -10.45 | Eps 0.010 | AvgScore50 0.36 | AvgLoss100 0.2264
# Ep 17500 | Steps 3096182 | Score   0 | EpReward -12.67 | Eps 0.010 | AvgScore50 0.50 | AvgLoss100 0.2029
# Ep 17550 | Steps 3104126 | Score   0 | EpReward  -7.18 | Eps 0.010 | AvgScore50 0.78 | AvgLoss100 0.2416
# Ep 17600 | Steps 3111814 | Score   0 | EpReward -19.21 | Eps 0.010 | AvgScore50 0.76 | AvgLoss100 0.2707
# Ep 17650 | Steps 3125209 | Score   0 | EpReward  -8.51 | Eps 0.010 | AvgScore50 2.00 | AvgLoss100 0.2451
# Ep 17700 | Steps 3141047 | Score   1 | EpReward -33.53 | Eps 0.010 | AvgScore50 2.60 | AvgLoss100 0.2275
# Ep 17750 | Steps 3152040 | Score   4 | EpReward  27.69 | Eps 0.010 | AvgScore50 1.58 | AvgLoss100 0.2260
# Ep 17800 | Steps 3162221 | Score   4 | EpReward  27.72 | Eps 0.010 | AvgScore50 1.34 | AvgLoss100 0.2701
# Ep 17850 | Steps 3175077 | Score   0 | EpReward -19.29 | Eps 0.010 | AvgScore50 2.04 | AvgLoss100 0.2052
# Ep 17900 | Steps 3186687 | Score   2 | EpReward  -5.43 | Eps 0.010 | AvgScore50 1.70 | AvgLoss100 0.2570
# Ep 17950 | Steps 3196642 | Score   0 | EpReward  -5.76 | Eps 0.010 | AvgScore50 1.22 | AvgLoss100 0.2127
# Ep 18000 | Steps 3206652 | Score   1 | EpReward   2.88 | Eps 0.010 | AvgScore50 1.38 | AvgLoss100 0.2564
# Ep 18050 | Steps 3217965 | Score   0 | EpReward  -9.09 | Eps 0.010 | AvgScore50 1.86 | AvgLoss100 0.2643
# Ep 18100 | Steps 3226673 | Score   1 | EpReward  -2.69 | Eps 0.010 | AvgScore50 1.30 | AvgLoss100 0.2737
# Ep 18150 | Steps 3238358 | Score   1 | EpReward   8.00 | Eps 0.010 | AvgScore50 1.90 | AvgLoss100 0.2258
# Ep 18200 | Steps 3247096 | Score   1 | EpReward  -8.22 | Eps 0.010 | AvgScore50 1.20 | AvgLoss100 0.2199
# Ep 18250 | Steps 3256811 | Score   0 | EpReward  -9.55 | Eps 0.010 | AvgScore50 1.28 | AvgLoss100 0.2076
# Ep 18300 | Steps 3266961 | Score   0 | EpReward  -5.72 | Eps 0.010 | AvgScore50 1.36 | AvgLoss100 0.1947
# Ep 18350 | Steps 3278073 | Score   1 | EpReward   9.95 | Eps 0.010 | AvgScore50 1.54 | AvgLoss100 0.1711
# Ep 18400 | Steps 3288467 | Score   0 | EpReward  -5.93 | Eps 0.010 | AvgScore50 1.40 | AvgLoss100 0.2335
# Ep 18450 | Steps 3297972 | Score   0 | EpReward  -5.02 | Eps 0.010 | AvgScore50 1.14 | AvgLoss100 0.2161
# Ep 18500 | Steps 3309132 | Score   1 | EpReward   6.52 | Eps 0.010 | AvgScore50 1.52 | AvgLoss100 0.2262
# Ep 18550 | Steps 3321792 | Score   3 | EpReward  16.89 | Eps 0.010 | AvgScore50 1.90 | AvgLoss100 0.2116
# Ep 18600 | Steps 3334033 | Score   6 | EpReward  76.57 | Eps 0.010 | AvgScore50 1.90 | AvgLoss100 0.2272
# Ep 18650 | Steps 3344749 | Score   1 | EpReward  11.02 | Eps 0.010 | AvgScore50 1.50 | AvgLoss100 0.2084
# Ep 18700 | Steps 3358595 | Score   1 | EpReward -13.10 | Eps 0.010 | AvgScore50 2.16 | AvgLoss100 0.2157
# Ep 18750 | Steps 3371209 | Score   4 | EpReward  36.30 | Eps 0.010 | AvgScore50 2.00 | AvgLoss100 0.1967
# Ep 18800 | Steps 3384295 | Score   2 | EpReward  12.06 | Eps 0.010 | AvgScore50 2.20 | AvgLoss100 0.2237
# Ep 18850 | Steps 3395410 | Score   0 | EpReward -16.93 | Eps 0.010 | AvgScore50 1.62 | AvgLoss100 0.1898
# Ep 18900 | Steps 3402828 | Score   0 | EpReward  -7.27 | Eps 0.010 | AvgScore50 0.56 | AvgLoss100 0.1842
# Ep 18950 | Steps 3409271 | Score   0 | EpReward  -8.65 | Eps 0.010 | AvgScore50 0.46 | AvgLoss100 0.1850
# Ep 19000 | Steps 3415464 | Score   1 | EpReward   6.41 | Eps 0.010 | AvgScore50 0.30 | AvgLoss100 0.2309
# Ep 19050 | Steps 3422315 | Score   1 | EpReward   0.31 | Eps 0.010 | AvgScore50 0.46 | AvgLoss100 0.2481
# Ep 19100 | Steps 3428971 | Score   0 | EpReward -15.57 | Eps 0.010 | AvgScore50 0.38 | AvgLoss100 0.2138
# Ep 19150 | Steps 3435925 | Score   0 | EpReward  -4.90 | Eps 0.010 | AvgScore50 0.46 | AvgLoss100 0.2357
# Ep 19200 | Steps 3443551 | Score   0 | EpReward  -3.64 | Eps 0.010 | AvgScore50 0.60 | AvgLoss100 0.2503
# Ep 19250 | Steps 3453180 | Score   7 | EpReward  93.72 | Eps 0.010 | AvgScore50 1.12 | AvgLoss100 0.2282
# Ep 19300 | Steps 3463651 | Score   0 | EpReward  -6.61 | Eps 0.010 | AvgScore50 1.24 | AvgLoss100 0.2415
# Ep 19350 | Steps 3477268 | Score   0 | EpReward -23.28 | Eps 0.010 | AvgScore50 1.98 | AvgLoss100 0.2609
# Ep 19400 | Steps 3491499 | Score   0 | EpReward  -9.83 | Eps 0.010 | AvgScore50 2.16 | AvgLoss100 0.2514
# Ep 19450 | Steps 3508063 | Score   0 | EpReward -14.50 | Eps 0.010 | AvgScore50 2.72 | AvgLoss100 0.2695
# Ep 19500 | Steps 3523786 | Score   3 | EpReward  25.17 | Eps 0.010 | AvgScore50 2.58 | AvgLoss100 0.2053
# Ep 19550 | Steps 3539510 | Score   4 | EpReward  34.85 | Eps 0.010 | AvgScore50 2.64 | AvgLoss100 0.2070
# Ep 19600 | Steps 3557070 | Score   5 | EpReward  41.64 | Eps 0.010 | AvgScore50 3.00 | AvgLoss100 0.1576
# Ep 19650 | Steps 3573766 | Score   2 | EpReward   8.84 | Eps 0.010 | AvgScore50 2.84 | AvgLoss100 0.1249
# Ep 19700 | Steps 3589195 | Score   0 | EpReward  -6.09 | Eps 0.010 | AvgScore50 2.50 | AvgLoss100 0.1460
# Ep 19750 | Steps 3603715 | Score   0 | EpReward  -6.48 | Eps 0.010 | AvgScore50 2.40 | AvgLoss100 0.1419
# Ep 19800 | Steps 3615779 | Score   1 | EpReward   9.81 | Eps 0.010 | AvgScore50 1.76 | AvgLoss100 0.1548
# Ep 19850 | Steps 3624654 | Score   5 | EpReward  59.12 | Eps 0.010 | AvgScore50 0.90 | AvgLoss100 0.1843
# Ep 19900 | Steps 3634822 | Score   2 | EpReward  14.55 | Eps 0.010 | AvgScore50 1.28 | AvgLoss100 0.1843
# Ep 19950 | Steps 3647068 | Score   0 | EpReward  -5.85 | Eps 0.010 | AvgScore50 1.64 | AvgLoss100 0.1831
# Ep 20000 | Steps 3657919 | Score   0 | EpReward  -8.71 | Eps 0.010 | AvgScore50 1.42 | AvgLoss100 0.1896
# Ep 20050 | Steps 3668959 | Score   1 | EpReward   2.68 | Eps 0.010 | AvgScore50 1.52 | AvgLoss100 0.1762
# Ep 20100 | Steps 3680148 | Score   0 | EpReward  -9.48 | Eps 0.010 | AvgScore50 1.54 | AvgLoss100 0.1943
# Ep 20150 | Steps 3693144 | Score   0 | EpReward  -9.32 | Eps 0.010 | AvgScore50 1.82 | AvgLoss100 0.2148
# Ep 20200 | Steps 3708983 | Score   0 | EpReward  -8.36 | Eps 0.010 | AvgScore50 2.50 | AvgLoss100 0.2084
# Ep 20250 | Steps 3726465 | Score   5 | EpReward  59.96 | Eps 0.010 | AvgScore50 3.00 | AvgLoss100 0.2070
